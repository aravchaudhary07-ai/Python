# %%
a=['arav','chaudhary','007']
print(a)
# Out:
# ['arav', 'chaudhary', '007']

# %%
a
# Out:
# ['arav', 'chaudhary', '007']

# %%
print(a[1])
# Out:
# chaudhary

# %%
a[1]
# Out:
# 'chaudhary'

# %%
a="hi i am arav"
age=18
b="my age is "
c=f"{a} {b}{age}"

# %%
c
# Out:
# 'hi i am arav my age is 18'

# %%
c=f"{a},{b}{age}"

# %%
c
# Out:
# 'hi i am arav,my age is 18'
