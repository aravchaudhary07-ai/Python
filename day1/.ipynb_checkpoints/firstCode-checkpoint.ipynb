# %%
print("hello world")
A=4
print(A)
# Out:
# hello world
# 4

# %%
A
# Out:
# 4

# %%
A=8

# %%
a="arav"
b="chaudhary"
c="007"
print(a+b+c)
# Out:
# aravchaudhary007

# %%
print(a,b,c)
# Out:
# arav chaudhary 007

# %%
print(a+" "+b+" "+c)
# Out:
# arav chaudhary 007

# %%
print(f"my age {A}")
# Out:
# my age 8

# %%
print(f"{a} {b}{c}")
# Out:
# arav chaudhary007
