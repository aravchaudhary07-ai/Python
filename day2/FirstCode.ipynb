# %%
list=[]
n=input("Enter number of items:")
for x in range(int(n)):
    new=input(f"enter {x+1} item:")
    list.append(new)
list
# Out:
# Enter number of items: 5
# enter 1 item: 1
# enter 2 item: 2
# enter 3 item: 3
# enter 4 item: 4
# enter 5 item: 5
# ['1', '2', '3', '4', '5']
